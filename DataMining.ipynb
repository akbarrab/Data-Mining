# %%
#Mengimport And Exporting Data
import pandas as pd
import numpy as np

# %%
#Menyambungkan Collab dengan My drive
from google.colab import drive
drive.mount('/content/gdrive')
df = pd.read_csv("gdrive/My Drive/Data Mining/data_penjualan.csv",)
df
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#       Tanggal;Jenis Produk;Jumlah Order;Harga;Total
# 0           05/08/2022;Foodpak260;1000;1800;1800000
# 1      05/08/2022;FoodpakMatte245;1000;1900;1900000
# 2      05/08/2022;CraftLaminasi290;5000;750;3750000
# 3     05/08/2022;CraftLaminasi290;1000;1200;1200000
# 4           07/08/2022;Dupleks310;1000;1550;1550000
# ...                                             ...
# 1071            14/11/2023;Ivory230;1000;900;900000
# 1072   15/11/2023;CraftLaminasi290;2000;800;1600000
# 1073   15/11/2023;CraftLaminasi290;1500;875;1312500
# 1074      15/11/2023;FoodpakMatte;1000;2200;2200000
# 1075         15/11/2023;GreaseProof;1000;300;300000
#
# [1076 rows x 1 columns]

# %%
#Menampilkan Data asli produk
df.values
# Out:
# array([['05/08/2022;Foodpak260;1000;1800;1800000'],
#        ['05/08/2022;FoodpakMatte245;1000;1900;1900000'],
#        ['05/08/2022;CraftLaminasi290;5000;750;3750000'],
#        ...,
#        ['15/11/2023;CraftLaminasi290;1500;875;1312500'],
#        ['15/11/2023;FoodpakMatte;1000;2200;2200000'],
#        ['15/11/2023;GreaseProof;1000;300;300000']], dtype=object)

# %%
#Transformasi setiap elemen dalam setiap baris Data Frame df menjadi string dan menyimpannya sebagai list of lists
data = [[str(element) for element in row] for row in df.values]
data #pemanggilan
# Out:
# [['05/08/2022;Foodpak260;1000;1800;1800000'],
#  ['05/08/2022;FoodpakMatte245;1000;1900;1900000'],
#  ['05/08/2022;CraftLaminasi290;5000;750;3750000'],
#  ['05/08/2022;CraftLaminasi290;1000;1200;1200000'],
#  ['07/08/2022;Dupleks310;1000;1550;1550000'],
#  ['08/08/2022;Dupleks310;500;1900;950000'],
#  ['08/08/2022;Ivory270;1000;1700;1700000'],
#  ['09/08/2022;Kinstruk130;1000;1000;1000000'],
#  ['09/08/2022;HVS;1500;850;1275000'],
#  ['09/08/2022;Dupleks350;500;1800;900000'],
#  ['09/08/2022;Dupleks350;500;1800;900000'],
#  ['10/08/2022;Dupleks310;500;1600;800000'],
#  ['10/08/2022;Ivory270;1000;2000;2000000'],
#  ['11/08/2022;CraftLaminasi290;1000;850;850000'],
#  ['11/08/2022;Dupleks350;500;1800;900000'],
#  ['11/08/2022;Dupleks350;500;1800;900000'],
#  ['11/08/2022;Dupleks310;2000;1300;2600000'],
#  ['12/08/2022;CraftLaminasi;1000;1200;1200000'],
#  ['12/08/2022;Ivory270;1000;2000;2000000'],
#  ['12/08/2022;Dupleks350;1000;2200;2200000'],
# ...

# %%
#Instal library mxltend
! pip install mlxtend

# %%
#mengimpor TransactionEncoder dari library mlxtend
from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder() #Membuat instance TransactionEncoder

data_encoded=te.fit(data).transform(data)# metode fit(data) mempelajari semua elemen unik dalam data. Lalu, transform(data) mengubah data transaksi ke dalam bentuk array NumPy

df = pd.DataFrame(data_encoded,columns=te.columns_)#membuat DataFrame df dari data_encoded
df = df.astype(int)#Mengonversi setiap nilai dalam df ke tipe int.
df#Menampilkan DataFrame
# Out:
#       01/01/2023;Dupleks310;1000;1800;1800000  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
# ...                                       ...
# 1071                                        0
# 1072                                        0
# 1073                                        0
# 1074                                        0
# 1075                                        0
#
#       01/01/2023;Dupleks310;1000;1900;1900000  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
# ...                                       ...
# 1071                                        0
# ...

# %%
from mlxtend.frequent_patterns import apriori,association_rules
frequent_itemsets = apriori(df, min_support=0.0005, use_colnames=True)# Menjalankan apriori dengan min_support lebih rendah

rules = association_rules (frequent_itemsets, metric="lift", min_threshold=1.0)# Menjalankan association rules jika ada frequent itemsets yang ditemukan
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
frequent_itemsets #Menampilkan frekuensi dataset
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        support                                        itemsets
# 0     0.000929       (01/01/2023;Dupleks310;1000;1800;1800000)
# 1     0.000929       (01/01/2023;Dupleks310;1000;1900;1900000)
# 2     0.000929       (01/01/2023;Dupleks310;2000;1650;3300000)
# 3     0.000929       (01/01/2023;Dupleks310;2000;1800;3600000)
# 4     0.000929       (01/01/2023;Dupleks310;2000;2000;4000000)
# ...        ...                                             ...
# 1031  0.000929       (31/08/2023;Greseproof40;2000;250;500000)
# 1032  0.000929         (31/08/2023;Ivory300;1000;3400;3400000)
# ...

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# Ubah df ke tipe bool untuk meningkatkan performa dan menghilangkan peringatan
df = df.astype(bool)

# Jalankan apriori untuk menemukan frequent itemsets
frequent_itemsets = apriori(df, min_support=0.0005, use_colnames=True)

# Memastikan ada frequent itemsets sebelum melanjutkan
if not frequent_itemsets.empty:
    # Jalankan association rules
    rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.0)

    # Tampilkan hasilnya
    print(rules[['antecedents', 'consequents', 'antecedent support', 'consequent support',
                 'support', 'confidence', 'lift', 'leverage', 'conviction', 'zhangs_metric']])
else:
    print("Tidak ada frequent itemsets yang ditemukan. Coba turunkan nilai min_support.")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, zhangs_metric]
# Index: []
